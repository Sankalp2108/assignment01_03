# %%
class foodie:
    
    permission = False
    admin = {}
    users = {}
    
    def __init__(self):
        self.admin_fun = self.admin_fun()
        self.users_fun = self.users_fun()
        
    def admin_register(self , name , password):
        self.admin[name] = password
        return "Register For Admin Successful"
        
    def user_register(self , name , phone_no , email , address , password):
        self.users[name] = password
        self.users["phone_no"] = phone_no
        self.users["email"] = email
        self.users["address"] = address
        return "User Register Successful"
        
    def admin_login(self , name , password):
        if name in self.admin:
            if self.admin[name] == password:
                self.permission = True
                return "Admin Login Successful"
            else:
                self.permission = False
                return "Admin Name and Password is incorrect"
        else:
            return "Admin Not Define"
        
    def user_login(self , name , password):
        if name in self.users:
            if self.users[name] == password:
                self.permission = False
                return "User Login Successful"
            else:
                self.permission = True
                return "Username and Password is incorrect"
        else:
            return "User not define"
        
        
#------------------------------------ Admin Function ----------------------------------------
        
        
    class admin_fun:
               
        key = 4
        food = { 1 : {"name" : "Tandoori Chicken" , "qantity" : 4 , "rupees" : 240 , "discount" : 10 , "stock" : 4} , 
                2 :  {"name" : "Vegan Burger" , "qantity" : 1 , "rupees" : 320, "discount" : 10 , "stock" : 1} ,
                3 :  {"name" : "Truffle Cake" , "qantity" : 500 , "rupees" : 900, "discount" : 10 , "stock" : 500}}

        def view(self):
                return self.food

        def add(self):
            self.food.update({self.key : {}})
            name = input("Enter food Name : ")
            qantity = int(input("Enter Food quantity : "))
            rupees = int(input("Enter Food Price : "))
            discount = int(input("Enter Discount on Food Item : "))
            stock = int(input("Enter Food in stock : "))
            self.food[self.key].update({"name" : name})
            self.food[self.key].update({"qantity" : qantity})
            self.food[self.key].update({"rupees" : rupees})
            self.food[self.key].update({"discount" : discount})
            self.food[self.key].update({"stock" : stock})
            self.key += 1

        def remove(self , key):
            self.food.pop(key)

        def edit(self , key):
            name = input("Enter food Name : ")
            qantity = int(input("Enter Food quantity : "))
            rupees = int(input("Enter Food Price : "))
            discount = int(input("Enter Discount on Food Item : "))
            stock = int(input("Enter Food in stock : "))
            self.food[key].update({"name" : name})
            self.food[key].update({"qantity" : qantity})
            self.food[key].update({"rupees" : rupees})
            self.food[key].update({"discount" : discount})
            self.food[key].update({"stock" : stock}) 
            
        
#-------------------------------------------- Users Function ------------------------------------------------
        
    class users_fun:
            
            food = { 1 : {"name" : "Tandoori Chicken" , "qantity" : 4 , "rupees" : 240 , "discount" : 10 , "stock" : 4} , 
                    2 :  {"name" : "Vegan Burger" , "qantity" : 1 , "rupees" : 320, "discount" : 10 , "stock" : 1} ,
                   3 :  {"name" : "Truffle Cake" , "qantity" : 500 , "rupees" : 900, "discount" : 10 , "stock" : 500}}
            key = []
            users = {}
            order_history = {}
            
    
            def place_new_order(self):
                print(self.food)
                self.key = list(map(int , input("Enter Food Id to select : ").split()))
                print("Selected Items Are : ")
                for i in self.key :
                    print(self.food[i])
                    self.order_history.update({i : self.food[i]})

            def update_profile(self):
                print("Update Your User Profile")
                name = input("Enter Your Name : ")
                phone_no = int(input("Enter Your Phone Number : "))
                email = input("Enter Your Email : ")
                address = input("Enter Your Address : ")
                password = input("Enter Your Password : ")
                self.users.update({name : password})
                self.users.update({"phone_No" : phone_no})
                self.users.update({"email" : email})
                self.users.update({"address" : address})

            def order(self):
                print("Your Order history is : ")
                return self.order_history
    



f1 = foodie()
f2 = f1.admin_fun
f3 = f1.users_fun


print("Choose Your Role.\n 1. Admin \n 2. User")
role = int(input("Enter 1 for Admin and 2 for User : "))

#----------------------------------- Register -------------------------------------------------
if role == 1:
    print("Register For Admin ")
    name = input("Enter Your Name : ")
    password = input("Enter Your Password : ")
    print(f1.admin_register(name , password))        
else:
    print("Register For User")
    name = input("Enter Your Name : ")
    phone_no = int(input("Enter Your Phone Number : "))
    email = input("Enter Your Email : ")
    address = input("Enter Your Address : ")
    password = input("Enter Your Password : ")
    print(f1.user_register(name , phone_no , email , address , password))
    

#------------------------------------- Login --------------------------------------

print("Login Here")
if role == 1:
    print("Enter Your Name and Password to Login")
    name = input("Enter Your Name : ")
    password = input("Enter Your Password :")
    print(f1.admin_login(name , password))
else:
    print("Enter Your Name and Password to Login")
    name = input("Enter Your Name : ")
    password = input("Enter Your Password :")
    print(f1.user_login(name , password))


if f1.permission:
    while True:
        print("Enter option.\n 1. Add new Food Item \n 2. Edit Food Item \n 3. View List of food items \n 4. Remove Food Item \n 5. Exit")
        option = int(input("Enter Your Number : "))
        while True:
            if option == 1:
                f2.add()
                print("Food Add Successfully")
                break
            elif option == 2:
                key = int(input("Enter  Food Id to Edit"))
                f2.edit(key)
                print("Food idtem Edited Successfully")
                break
            elif option == 3:
                print(f2.view())
                break
            elif option == 4:
                key = int(input("Enter  Food Id to Remove"))
                f2.remove(key)
                print("Food Item Remove Successfully")
                break
            elif option == 5:
                break
            else:
                print("Invalid Input")
                break
        if option == 5:
            break
        else:
            pass        
else:
    while True:
        print("Enter option.\n 1. Place New Order \n 2. Order History \n 3. Update Profile \n 4. Exit")
        option = int(input("Enter Your Number : "))
        while True:
            if option == 1:
                f3.place_new_order()
                print("Oder Successfully Added")
                break
            elif option == 2:
                print(f3.order())
                break
            elif option == 3:
                f3.update_profile()
                print("Profile Update Successfully")
                break
            elif option == 4:
                break
            else:
                print("Invalid Input")
                break
        if option == 4:
            break
        else:
            pass
